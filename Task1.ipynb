# %% [markdown]
# Задача 1. Когда используется критерий Стьюдента, а когда Z –критерий?
#
# Ответ:
#
# Мы выбираем Z критерий, если известна СКО(сигма) генеральной совокупности
#
# Если СКО (сигма) не известна, мы выбираем критерий Стьюдента
